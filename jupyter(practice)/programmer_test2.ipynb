# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:12 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:13 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,803 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,210 kB]
# Fetched 5,265 kB in 4s (1,242 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (94.0.4606.71-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import os

url = f"https://programmers.co.kr/job?min_salary=&min_career=&min_employees=&order=recent&page=1"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless') #내부 창을 띄울 수 없으므로 설정
chrome_options.add_argument('no-sandbox')
chrome_options.add_argument('disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver',options=chrome_options)
driver.get(url)

time.sleep(1)

def get_last():
    pages = driver.find_elements_by_class_name("page-link")
    last = int(pages[-2].text)
    return last
def get_urls(last):
    links=[]
    for page in range(1, last+1):
      urls = driver.get(f"https://programmers.co.kr/job?min_salary=&min_career=&min_employees=&order=recent&page={page}")
      time.sleep(1)
      print(f"{page} 스크랩 중")
  #         html = driver.page_source
  #         soup = bs4.BeautifulSoup(html,"html.parser")
  #         hrefs = soup.select(.position-title).get['href']
      js = 'return [...document.querySelectorAll(".position-title a")].map(a=>a.href)'
      hrefs = driver.execute_script(js)

      for href in hrefs:
        link = href
        links.append(link)
    return links
def get_info(links):
    recruit=[]
    for link in links:
      informations = {}
      stackinfo = []
      url = link
      driver.get(url)
      time.sleep(1)
      company = driver.find_elements_by_xpath("//h4[@class='sub-title'][1]")
      notice = driver.find_elements_by_xpath("//h2[@class='title']")
      
      stacks = driver.find_elements_by_xpath("//tr[@class='heavy-use']//td//code")
      index = driver.find_elements_by_xpath("//tbody//tr//td[@class='t-label']")
      content = driver.find_elements_by_xpath("//td[@class='t-content']")
      for c,n in zip(company,notice):
  
        company = c.text
        notice = n.text
      for s in stacks:
        stack = s.text
        stackinfo.append(stack)
      for i,c in zip(index,content):
        info = i.text
        content = c.text
        informations[info]=content
      doc = {
        'company':company,
        'notice':notice,
        'information':informations,
        'stacks':stackinfo
      }
      recruit.append(doc)
    return recruit

# %%
result = get_urls(get_last())
a = get_info(result)
# Out:
# 1 스크랩 중
# 2 스크랩 중
# 3 스크랩 중
# 4 스크랩 중
# 5 스크랩 중
# 6 스크랩 중
# 7 스크랩 중
# 8 스크랩 중
# 9 스크랩 중
# 10 스크랩 중
# 11 스크랩 중
# 12 스크랩 중
# 13 스크랩 중
# 14 스크랩 중
# 15 스크랩 중
# 16 스크랩 중
# 17 스크랩 중
# 18 스크랩 중
# 19 스크랩 중
# 20 스크랩 중
# 21 스크랩 중
# 22 스크랩 중
# 23 스크랩 중
# 24 스크랩 중
# 25 스크랩 중
# 26 스크랩 중
# 27 스크랩 중
# 28 스크랩 중
# 29 스크랩 중
# 30 스크랩 중
# 31 스크랩 중
# 32 스크랩 중
# 33 스크랩 중
# 34 스크랩 중
# 35 스크랩 중
# 36 스크랩 중
# 37 스크랩 중
# 38 스크랩 중
# 39 스크랩 중
# 40 스크랩 중
# 41 스크랩 중
# 42 스크랩 중
# 43 스크랩 중
# 44 스크랩 중
# 45 스크랩 중
# 46 스크랩 중
# 47 스크랩 중
# 48 스크랩 중
# 49 스크랩 중
# 50 스크랩 중
# 51 스크랩 중
# 52 스크랩 중
# 53 스크랩 중
# 54 스크랩 중
# 55 스크랩 중
# 56 스크랩 중
# 57 스크랩 중
# 58 스크랩 중
# 59 스크랩 중
# 60 스크랩 중
# 61 스크랩 중
# 62 스크랩 중
# 63 스크랩 중
# 64 스크랩 중
# 65 스크랩 중
# 66 스크랩 중
# 67 스크랩 중
# 68 스크랩 중
# 69 스크랩 중
# 70 스크랩 중
# 71 스크랩 중
# 72 스크랩 중
# 73 스크랩 중

# %%
a

# %%
import json
def toJson(a):
    with open('recruit.json', 'w', encoding='utf-8') as file :
        json.dump(a, file, ensure_ascii=False, indent='\t')


toJson(a)

# %%
len(a)
# Out:
# 1447

# %%
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import os
import csv

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless') #내부 창을 띄울 수 없으므로 설정
chrome_options.add_argument('no-sandbox')
chrome_options.add_argument('disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver',options=chrome_options)
links = ['https://programmers.co.kr/job_positions/7126','https://programmers.co.kr/job_positions/7128']

recruit=[]
for link in links:
  informations = {}
  stackinfo = []
  url = link
  driver.get(url)
  time.sleep(3)
  company = driver.find_elements_by_xpath("//h4[@class='sub-title'][1]")
  notice = driver.find_elements_by_xpath("//h2[@class='title']")
  
  stacks = driver.find_elements_by_xpath("//tr[@class='heavy-use']//td//code")
  index = driver.find_elements_by_xpath("//tbody//tr//td[@class='t-label']")
  content = driver.find_elements_by_xpath("//td[@class='t-content']")
  for c,n in zip(company,notice):
  
    company = c.text
    notice = n.text
  for s in stacks:
    stack = s.text
    stackinfo.append(stack)
  for i,c in zip(index,content):
    info = i.text
    content = c.text
    informations[info]=content
  doc = {
    'company':company,
    'notice':notice,
    'information':informations,
    'stacks':stackinfo
  }
  recruit.append(doc)
    
recruit
# Out:
# [{'company': '큐픽스',
#   'information': {'Company Size': '38',
#    'Employment Type': 'Full-time',
#    'Experiences': '1 ~ 10years',
#    'Period': 'from 2021-09-07 10:37 to 2021-10-31 23:59',
#    'Position': '인공지능(AI)',
#    'Principal Services': '3d digital twin for construction',
#    'Work Location': '경기 성남시 분당구 대왕판교로 670, (삼평동) B동 605호'},
#   'notice': '[전문연구요원] 컴퓨터비전, 머신러닝, 딥러닝 (CNN)',
#   'stacks': ['C++', 'Tensorflow', 'PyTorch', 'Python']},
#  {'company': '큐픽스',
#   'information': {'Company Size': '38',
#    'Employment Type': 'Full-time',
#    'Experiences': '1 ~ 10years',
#    'Period': 'from 2021-09-07 10:50 to 2021-10-31 23:59',
#    'Position': '프론트엔드, 웹 풀스택, 응용 프로그램',
#    'Principal Services': '3d digital twin for construction',
#    'Work Location': '경기 성남시 분당구 대왕판교로 670, (삼평동) B동 605호'},
#   'notice': '[전문연구요원/프론트엔드] Angular/3D/WebGL/Computer Graphics',
#   'stacks': ['TypeScript', 'JavaScript', 'AngularJS']}]
